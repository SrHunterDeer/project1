# %%
import pandas as pd
import matplotlib.pyplot as plt
url_cleaned = 'https://raw.githubusercontent.com/SrHunterDeer/project1/refs/heads/main/project%20managerment/data%202/clean%20data/cleaned_data.csv'
df = pd.read_csv(url_cleaned)
print("Dữ liệu 5 dòng đầu tiên:")
display(df.head())
print("\nDanh sách các cột trong file:")
print(df.columns.tolist())
# Out:
# Dữ liệu 5 dòng đầu tiên:
#   ACCOUNT_ID  CREDIT_LIMIT_VND  GENDER  EDUCATION_LEVEL  MARITAL_STATUS  \
# 0  ACC000001          15000000       0                2               1
# 1  ACC000002         100000000       0                2               0
# 2  ACC000003          75000000       0                2               0
# 3  ACC000004          40000000       0                2               1
# 4  ACC000005          40000000       1                2               1
#
#    AGE_YEARS  SUPPLEMENTARY_CARD_HOLDER  PAY_STATUS_M1  PAY_STATUS_M2  \
# 0         24                          0              2              2
# 1         27                          0             -1              2
# 2         35                          0              0              0
# 3         38                          0              0              0
# 4         57                          0             -1              0
#
#    PAY_STATUS_M3  ...  BILL_AMOUNT_M4_VND  BILL_AMOUNT_M5_VND  \
# ...

# %%
plt.figure(figsize=(8, 5))
df['NEXT_MONTH_DEFAULT'].value_counts().sort_index().plot(kind='bar', color=['skyblue', 'salmon'], edgecolor='black')
plt.title('Số lượng khách hàng vỡ nợ vs không vỡ nợ', fontsize=14, fontweight='bold')
plt.xlabel('Trạng thái (0 = không, 1 = có)', fontsize=12)
plt.ylabel('Số lượng', fontsize=12)
plt.xticks(rotation=0)
plt.show()

weights = np.ones(len(df['AGE_YEARS'])) / len(df['AGE_YEARS']) * 100
plt.figure(figsize=(8, 5))
plt.hist(df['AGE_YEARS'], bins=20, color='lightgreen', edgecolor='black', weights=weights)
plt.title('Phân bố độ tuổi khách hàng (Tỷ lệ %)', fontsize=14, fontweight='bold')
plt.xlabel('Tuổi', fontsize=12)
plt.ylabel('Tỷ trọng (%)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
limit_in_millions = df['CREDIT_LIMIT_VND'] / 1_000_000
weights = np.ones(len(limit_in_millions)) / len(limit_in_millions) * 100
plt.figure(figsize=(10, 6))
plt.hist(limit_in_millions, bins=20, color='orange', edgecolor='black', alpha=0.7, weights=weights)
plt.title('Phân bổ hạn mức thẻ tín dụng (Tỷ trọng %)', fontsize=14, fontweight='bold')
plt.xlabel('Hạn mức (triệu VND)', fontsize=12)
plt.ylabel('Tỷ trọng (%)', fontsize=12) 
plt.ticklabel_format(style='plain', axis='x')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.3) 
plt.tight_layout()
plt.show()
